# %% [markdown]
# Hunter Bennett | Glass Lab | Kupffer Strains Project | 24 Jan 2023
#
# Notebook to generate Upset plots describing overlap of active enhancers

# %% [markdown]
# ### Load packages, set plot parameters

# %%
### header ###
__author__ = "Hunter Bennett"
__license__ = "BSD"
__email__ = "hunter.r.bennett@gmail.com"
# %load_ext autoreload
# %autoreload 2
### imports ###
import os
import re
import glob
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import upsetplot as upset

# %% [markdown]
# Set working directory

# %%
workingDirectory = '/home/h1bennet/strains_github/results/Figure2_H3K27Ac/'
if not os.path.isdir(workingDirectory):
    os.mkdir(workingDirectory)
os.chdir(workingDirectory)

# %% [markdown]
# Define custom functions

# %%
def read_annotated_peaks(path, filter_sex_unknown=True):
    '''This function imports an annotated homer peak file using
    pandas read_csv function. It also performes common preprocessing steps
    such as placing the peak IDs in the index and filtering so that
    only autosomal peaks are included. Also renames index to peakID.
       
       Accepts:
           path (str): path to expression file
           filter_sex_unkown (bool): filter unknown chromosomes
           and sex chromosomes - focus analysis on autosomal chr.
       
       Returns:
           df (pandas.Dataframe): genes by samples with annotation.
           mat (pandas.DataFrame): genes by samples without annotation.
       '''
    # import functions
    import pandas as pd

    df = pd.read_csv(path, sep='\t', index_col=0)

    # rename index
    df.index.rename('PeakID', inplace=True)
    # rename sample columns so they are shorter (can add .str.split('/').str[-1] to shorten even more
    df = df.rename(
        columns=dict(zip(df.iloc[:, 18:].columns.values,
                         pd.Series(df.iloc[:, 18:].columns.values).str.split(' Tag Count').str[0])))

    
    # filter unknown and sex chromosomes
    autosomes = ['chr1', 'chr2', 'chr3', 'chr4',
                 'chr5', 'chr6', 'chr7', 'chr8',
                 'chr9', 'chr10', 'chr11', 'chr12',
                 'chr13', 'chr14', 'chr15', 'chr16',
                 'chr17', 'chr18', 'chr19']

    df = df.loc[df.Chr.str.contains('|'.join(autosomes)), :]
      
    mat = df.iloc[:, 18:]
        
    return (df, mat)

# %%
#### PLOTTING PARAMETERS FOR MANUSCRIPT ####
# # get matplotlib to save readable fonts
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
matplotlib.rcParams['font.size'] = 8
matplotlib.rcParams['savefig.dpi'] = 500


# line widths
matplotlib.rcParams['axes.linewidth'] = 1
matplotlib.rcParams['xtick.major.width'] = 1
matplotlib.rcParams['ytick.major.width'] = 1

# adjust defualt color for plots to black
# normal default is a dark gray
COLOR = 'black'
matplotlib.rcParams['text.color'] = COLOR
matplotlib.rcParams['axes.labelcolor'] = COLOR
matplotlib.rcParams['xtick.color'] = COLOR
matplotlib.rcParams['ytick.color'] = COLOR
matplotlib.rcParams['axes.edgecolor'] = COLOR

#### PLOT PARAMETERS FOR THIS PLOT ####

# %% [markdown]
# Read in annotation files

# %%
# import annotation file
df, mat = read_annotated_peaks(
    'https://zenodo.org/record/7829622/files/idr_peaks_h3k27ac_norm.txt')

df.to_csv('./idr_peaks_h3k27ac_norm.txt', sep='\t')

# %%
df.head()
# Out:
#                             Chr      Start        End Strand  Peak Score  \
# PeakID
# Merged-chr5-143622461-3    chr5  143621940  143622940      +      1000.0
# Merged-chr11-100814679-3  chr11  100814172  100815172      +      1000.0
# Merged-chr6-91712963-3     chr6   91712457   91713457      +      1000.0
# Merged-chr17-70831832-3   chr17   70831391   70832391      +      1000.0
# Merged-chr10-13868970-3   chr10   13868505   13869505      +      1000.0
#
#                                                     Focus Ratio/Region Size  \
# PeakID
# Merged-chr5-143622461-3   ./atac_peak_files/aj_kupffer_control_young.idr...
# Merged-chr11-100814679-3  ./atac_peak_files/aj_kupffer_control_young.idr...
# Merged-chr6-91712963-3    ./atac_peak_files/aj_kupffer_control_young.idr...
# Merged-chr17-70831832-3   ./atac_peak_files/aj_kupffer_control_young.idr...
# Merged-chr10-13868970-3   ./atac_peak_files/aj_kupffer_control_young.idr...
#
#                                                      Annotation  \
# PeakID
# Merged-chr5-143622461-3                promoter-TSS (NM_011182)
# Merged-chr11-100814679-3  intron (NM_001113563, intron 1 of 18)
# Merged-chr6-91712963-3       intron (NM_009320, intron 2 of 14)
# Merged-chr17-70831832-3                              Intergenic
# Merged-chr10-13868970-3             promoter-TSS (NM_001347362)
#
#                                             Detailed Annotation  \
# PeakID
# Merged-chr5-143622461-3                promoter-TSS (NM_011182)
# Merged-chr11-100814679-3  intron (NM_001113563, intron 1 of 18)
# Merged-chr6-91712963-3       intron (NM_009320, intron 2 of 14)
# Merged-chr17-70831832-3                       MTD|LTR|ERVL-MaLR
# Merged-chr10-13868970-3             promoter-TSS (NM_001347362)
#
#                           Distance to TSS Nearest PromoterID  ...  \
# PeakID                                                        ...
# Merged-chr5-143622461-3              -7.0          NM_011182  ...
# Merged-chr11-100814679-3           7898.0          NM_011489  ...
# Merged-chr6-91712963-3            28890.0          NM_009320  ...
# Merged-chr17-70831832-3           14886.0       NM_001164077  ...
# Merged-chr10-13868970-3             -48.0       NM_001347362  ...
#
#                                Gene Type h3k27ac_AJ_Kupffer_Control_rep1  \
# PeakID
# Merged-chr5-143622461-3   protein-coding                          115.55
# Merged-chr11-100814679-3  protein-coding                           31.46
# Merged-chr6-91712963-3    protein-coding                          161.89
# Merged-chr17-70831832-3   protein-coding                          247.13
# Merged-chr10-13868970-3   protein-coding                          199.07
#
#                          h3k27ac_AJ_Kupffer_Control_rep3  \
# PeakID
# Merged-chr5-143622461-3                            88.01
# Merged-chr11-100814679-3                           26.73
# Merged-chr6-91712963-3                            176.48
# Merged-chr17-70831832-3                           206.43
# Merged-chr10-13868970-3                           140.08
#
#                          h3k27ac_AJ_Kupffer_Control_rep2  \
# PeakID
# Merged-chr5-143622461-3                            87.87
# Merged-chr11-100814679-3                           35.15
# Merged-chr6-91712963-3                            151.69
# Merged-chr17-70831832-3                           138.74
# Merged-chr10-13868970-3                            83.25
#
#                          h3k27ac_BALBcJ_Kupffer_Control_rep1  \
# PeakID
# Merged-chr5-143622461-3                               124.82
# Merged-chr11-100814679-3                               24.96
# Merged-chr6-91712963-3                                211.19
# Merged-chr17-70831832-3                               239.52
# Merged-chr10-13868970-3                               178.80
#
#                          h3k27ac_BALBcJ_Kupffer_Control_rep3  \
# PeakID
# Merged-chr5-143622461-3                                97.50
# Merged-chr11-100814679-3                               24.72
# Merged-chr6-91712963-3                                150.68
# Merged-chr17-70831832-3                               153.01
# Merged-chr10-13868970-3                               150.22
#
#                          h3k27ac_BALBcJ_Kupffer_Control_rep2  \
# PeakID
# Merged-chr5-143622461-3                               114.94
# Merged-chr11-100814679-3                               32.96
# Merged-chr6-91712963-3                                151.92
# Merged-chr17-70831832-3                               246.76
# Merged-chr10-13868970-3                                79.58
#
#                          h3k27ac_C57_Kupffer_Control_rep1  \
# PeakID
# Merged-chr5-143622461-3                            115.12
# Merged-chr11-100814679-3                            33.80
# Merged-chr6-91712963-3                             173.21
# Merged-chr17-70831832-3                            188.00
# Merged-chr10-13868970-3                            192.23
#
#                           h3k27ac_C57_Kupffer_Control_rep3  \
# PeakID
# Merged-chr5-143622461-3                             106.56
# Merged-chr11-100814679-3                             32.72
# Merged-chr6-91712963-3                              175.54
# Merged-chr17-70831832-3                             221.53
# Merged-chr10-13868970-3                             141.05
#
#                           h3k27ac_C57_Kupffer_Control_rep2
# PeakID
# Merged-chr5-143622461-3                              74.94
# Merged-chr11-100814679-3                             31.23
# Merged-chr6-91712963-3                              128.03
# Merged-chr17-70831832-3                             124.91
# Merged-chr10-13868970-3                              58.71
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Generate UpSet plot summarizing overlap of poised enhancers in each group

# %%
groups = ['AJ', 'BALBcJ', 'C57Bl6J']
columns = [mat.columns.str.contains('AJ_Kupffer_Control'),
           mat.columns.str.contains('BALBcJ_Kupffer_Control'),
           mat.columns.str.contains('C57_Kupffer_Control')]

avg_tags = {}

for group, col in zip(groups, columns):
    avg_tags[group] = mat.iloc[:, col].mean(1)
    
avg_tags_df = pd.DataFrame(avg_tags)

# %% [markdown]
# Filter low tag peaks.
# Require at least one group to have an average tag count above minimum threshold, in this case 2^5

# %%
thresh=32

peak_dict = {}
for col in avg_tags_df.columns:
    peak_dict[col] = avg_tags_df.index[avg_tags_df[col]>thresh].tolist()

# %%
peak_list_upset = upset.from_contents(peak_dict)
p = upset.UpSet(peak_list_upset, orientation="horizontal", sort_categories_by='input')
p.style_subsets(present=["AJ"], absent=["BALBcJ", "C57Bl6J"], facecolor="#e41a1c",
                    linewidth=2)
p.style_subsets(present=["BALBcJ"], absent=["AJ", "C57Bl6J"], facecolor="#377eb8",
                    linewidth=2)
p.style_subsets(present=["C57Bl6J"], absent=["BALBcJ", "AJ"], facecolor="#4daf4a",
                    linewidth=2)
p.plot()
plt.gca().set_title("Active Enhancers")
# Out:
# Text(0.5, 1.0, 'Active Enhancers')
